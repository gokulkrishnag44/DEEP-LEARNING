# %% [markdown]
# # <span style = "color:IndianRed; font-size:40px"> Brain Tumor Classification (MRI)</span>

# %% [markdown]
# ***

# %% [markdown]
# A Brain tumor is considered as one of the aggressive diseases, among children and adults. Brain tumors account for 85 to 90 percent of all primary Central Nervous System(CNS) tumors. Every year, around 11,700 people are diagnosed with a brain tumor. The 5-year survival rate for people with a cancerous brain or CNS tumor is approximately 34 percent for men and36 percent for women. Brain Tumors are classified as: Benign Tumor, Malignant Tumor, Pituitary Tumor, etc. Proper treatment, planning, and accurate diagnostics should be implemented to improve the life expectancy of the patients. The best technique to detect brain tumors is Magnetic Resonance Imaging (MRI). A huge amount of image data is generated through the scans. These images are examined by the radiologist. A manual examination can be error-prone due to the level of complexities involved in brain tumors and their properties.
# Application of automated classification techniques using Machine Learning(ML) and Artificial Intelligence(AI)has consistently shown higher accuracy than manual classification. Hence, proposing a system performing detection and classification by using Deep Learning Algorithms using ConvolutionNeural Network (CNN), Artificial Neural Network (ANN), and TransferLearning (TL) would be helpful to doctors all around the world.

# %% [markdown]
# ## Context

# %% [markdown]
# Brain Tumors are complex.  There are lot of abnormalities in the sizes and location of the brain tumor(s). This makes it really difficult for complete understanding of the nature of the tumor. Also, a professional Neurosurgeon is required for MRI analysis. Often times in developing countries the lack of skillful doctors and lack of knowledge about tumors makes it really challenging an time-consuming to generate reports from MRI. So an automated system can solve this problem.

# %% [markdown]
# ## Definition

# %% [markdown]
# To Detect and Classify Brain Tumor using CNN, and TL; as an asset of Deep Learning and to examine the tumor position(segmentation).

# %% [markdown]
# ## Let's Begin

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.utils import shuffle
from skimage.transform import resize
from sklearn.metrics import confusion_matrix
import glob

# %% [markdown]
# ### Fetch the training Data

# %% [markdown]
# #### Use glob

# %% [markdown]
# The data contains 4 subclasses. Store all 4 in different variables

# %%
giloma_tumor=glob.glob('Brain_tumor/Training/glioma_tumor/*jpg')
meningioma_tumor=glob.glob('Brain_tumor/Training/meningioma_tumor/*jpg')
no_tumor=glob.glob('Brain_tumor/Training/no_tumor/*jpg')
pituitary_tumor=glob.glob('Brain_tumor/Training/pituitary_tumor/*jpg')

# %%
len(giloma_tumor)
# Out:
# 84

# %% [markdown]
# ### Fetch the testing data

# %%
giloma_tumor_test=glob.glob('Brain_tumor/Testing/glioma_tumor/*jpg')
meningioma_tumor_test=glob.glob('Brain_tumor/Testing/meningioma_tumor/*jpg')
no_tumor_test=glob.glob('Brain_tumor/Testing/no_tumor/*jpg')
pituitary_tumor_test=glob.glob('Brain_tumor/Testing/pituitary_tumor/*jpg')

#\Brain Tumour Classification Files\Brain_tumor\Testing

# %% [markdown]
# ### Find the number of images of all classes in the Training set

# %%
print('Number of images in each training set:')
print('Giloma tumor:{}'.format(len(giloma_tumor)))
print('Meningioma Tumor:{}'.format(len(meningioma_tumor)))
print('No Tumor:{}'.format(len(no_tumor)))
print('Pituitary Tumor:{}'.format(len(pituitary_tumor)))
# Out:
# Number of images in each training set:
# Giloma tumor:84
# Meningioma Tumor:72
# No Tumor:72
# Pituitary Tumor:84

# %% [markdown]
# ### Find the number of images of all classes in the testing set

# %%
print('Number of images in each training set:')
print('Giloma tumor:{}'.format(len(giloma_tumor_test)))
print('Meningioma Tumor:{}'.format(len(meningioma_tumor_test)))
print('No Tumor:{}'.format(len(no_tumor_test)))
print('Pituitary Tumor:{}'.format(len(pituitary_tumor_test)))
# Out:
# Number of images in each training set:
# Giloma tumor:24
# Meningioma Tumor:24
# No Tumor:24
# Pituitary Tumor:24

# %% [markdown]
# ### Store all the images inside a list and create a list with the corresponding labels

# %% [markdown]
# ### For Training set

# %%
images=[]
label=[]
for i in giloma_tumor:
    img=plt.imread(i)
    images.append(img)
    label.append(0)
for i in meningioma_tumor:
    img=plt.imread(i)
    images.append(img)
    label.append(1)
for i in no_tumor:
    img=plt.imread(i)
    images.append(img)
    label.append(2)
for i in pituitary_tumor:
    img=plt.imread(i)
    images.append(img)
    label.append(3)

# %% [markdown]
# ### For Testing set

# %%
test_image=[]
test_label=[]

for i in giloma_tumor_test:
    img=plt.imread(i)
    test_image.append(img)
    test_label.append(0)
for i in meningioma_tumor_test:
    img=plt.imread(i)
    test_image.append(img)
    test_label.append(1)
for i in no_tumor_test:
    img=plt.imread(i)
    test_image.append(img)
    test_label.append(2)
for i in pituitary_tumor_test:
    img=plt.imread(i)
    test_image.append(img)
    test_label.append(3)

# %% [markdown]
# ### Shuffle both image list and label list (In both Training and testing set)

# %% [markdown]
# #### Use shuffle function from sklearn utils

# %%
print(len(test_image))
print(len(images))
# Out:
# 96
# 312

# %%
plt.figure(figsize=(10,5))
for i in range(15):
    plt.subplot(3,5,i+1)
    plt.imshow(images[i])
    plt.title(label[i])
plt.tight_layout()

# %%
images,label=shuffle(images,label,random_state=100)

# %%
test_image,test_label=shuffle(test_image,test_label,random_state=100)

# %%
label_names={0:'glioma tumor',1:'meningioma tumor',2:'no tumor',3:'pituitary'}

# %% [markdown]
# ### Plot a few images from our shuffled list with its corresponding label (Either from training or test set)

# %%
plt.figure(figsize=(10,5))
for i in range(15):
    plt.subplot(3,5,i+1)
    plt.imshow(images[i])
    plt.title(label_names[label[i]])
plt.tight_layout()

# %% [markdown]
# ### Check the shape of the first 10 images in our list (Either from training or test set)

# %%
for i in range(10):
    print(images[i].shape)
# Out:
# (512, 512, 3)
# (630, 630, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)

# %% [markdown]
# ### Reshape the images to 224x224( For both training and testing set)

# %% [markdown]
# Also reassign them to new variables named X_train and X_test and convert them to a numpy array

# %%
x_train=[]
for i in images:
    x_train.append(resize(i,(224,224,3)))

# %%
x_test=[]
for i in test_image:
    x_test.append(resize(i,(224,224,3)))

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

# %%
y_train=np.array(label)
y_test=np.array(test_label)

# %%
y_test.shape
# Out:
# (96,)

# %% [markdown]
# ### Create numpy arrays named y_train and y_test from our training and testing label lists we created earlier

# %%
plt.figure(figsize=(10,5))
for i in range(15):
    plt.subplot(3,5,i+1)
    plt.imshow(x_train[i])
    plt.title(label_names[label[i]])
plt.tight_layout()

# %% [markdown]
# ### Plot some of our reshaped images

# %% [markdown]
# ### Check the shape of X_train and X_test and y_train and y_test

# %%
print(f"Shape of x_train :{x_train.shape}")
print(f"Shape of y_train :{y_train.shape}")
print(f"Shape of x_test :{x_test.shape}")
print(f"Shape of y_test :{y_test.shape}")
# Out:
# Shape of x_train :(312, 224, 224, 3)
# Shape of y_train :(312,)
# Shape of x_test :(96, 224, 224, 3)
# Shape of y_test :(96,)

# %% [markdown]
# ### Create a keras Sequential model with convolution layers, Flatten and  Hidden layers

# %%
model=keras.models.Sequential([
    keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(224,224,3)),
    keras.layers.MaxPool2D(2,2),
    
    keras.layers.Conv2D(16,(3,3),activation='relu'),
    keras.layers.MaxPool2D(2,2),
    
    keras.layers.Flatten(),
    
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(4,activation='sigmoid')
])

# %% [markdown]
# ### Compile the model

# %% [markdown]
# #### Use 'sparse_categorical_crossentropy' for loss

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Check the summary of our model

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 222, 222, 16)      448
#
#  max_pooling2d_10 (MaxPoolin  (None, 111, 111, 16)     0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 109, 109, 16)      2320
#
#  max_pooling2d_11 (MaxPoolin  (None, 54, 54, 16)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 46656)             0
#
#  dense_10 (Dense)            (None, 64)                2986048
#
#  dense_11 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 2,989,076
# Trainable params: 2,989,076
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model.
# Make sure to include a validation data with validation_split

# %%
model.fit(x_train,y_train,epochs=10,validation_split=0.10)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 4s 410ms/step - loss: 1.8490 - accuracy: 0.3714 - val_loss: 1.3021 - val_accuracy: 0.5312
# Epoch 2/10
# 9/9 [==============================] - 3s 357ms/step - loss: 1.1594 - accuracy: 0.5821 - val_loss: 1.1247 - val_accuracy: 0.4688
# Epoch 3/10
# 9/9 [==============================] - 3s 348ms/step - loss: 0.8538 - accuracy: 0.7357 - val_loss: 0.7743 - val_accuracy: 0.7188
# Epoch 4/10
# 9/9 [==============================] - 3s 352ms/step - loss: 0.4912 - accuracy: 0.8964 - val_loss: 0.5187 - val_accuracy: 0.7812
# Epoch 5/10
# 9/9 [==============================] - 3s 351ms/step - loss: 0.2563 - accuracy: 0.9500 - val_loss: 0.4702 - val_accuracy: 0.8125
# Epoch 6/10
# 9/9 [==============================] - 3s 350ms/step - loss: 0.1419 - accuracy: 0.9643 - val_loss: 0.1869 - val_accuracy: 0.9062
# Epoch 7/10
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0640 - accuracy: 0.9893 - val_loss: 0.1344 - val_accuracy: 0.9375
# Epoch 8/10
# 9/9 [==============================] - 3s 360ms/step - loss: 0.0308 - accuracy: 0.9964 - val_loss: 0.1564 - val_accuracy: 0.9062
# Epoch 9/10
# 9/9 [==============================] - 3s 386ms/step - loss: 0.0180 - accuracy: 0.9964 - val_loss: 0.0834 - val_accuracy: 0.9688
# Epoch 10/10
# 9/9 [==============================] - 3s 370ms/step - loss: 0.0174 - accuracy: 0.9964 - val_loss: 0.1332 - val_accuracy: 0.9375

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(x_train,y_train)
# Out:
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0240 - accuracy: 0.9936
# [0.024038344621658325, 0.9935897588729858]

# %%
# Out:
# 10/10 [==============================] - 8s 803ms/step - loss: 0.1365 - accuracy: 0.9647
# [0.13646499812602997, 0.9647436141967773]

# %% [markdown]
# ### Make predictions with X_test

# %%
y_pred=model.predict(x_test)
# Out:
# 3/3 [==============================] - 0s 78ms/step

# %%
# Out:
# array([[3.96158173e-09, 2.59192660e-07, 1.04352678e-08, 1.22434884e-01],
#        [4.91268474e-06, 1.90019608e-04, 6.44176362e-06, 5.02902687e-01],
#        [1.65888886e-10, 3.21482077e-07, 3.92973423e-02, 5.72746813e-01],
#        [2.73172821e-11, 5.42746825e-08, 1.39520839e-08, 3.94334674e-01],
#        [4.45670723e-10, 1.07088685e-03, 8.26060358e-08, 4.83083725e-03]],
#       dtype=float32)

# %% [markdown]
# ### Use np.argmax to fetch indices of max element of the array

# %% [markdown]
# Store the values in a list

# %%
y_pred[:5]
# Out:
# array([[9.9629015e-01, 9.8922896e-01, 9.9970061e-01, 1.8396446e-01],
#        [5.3559780e-02, 1.8812823e-03, 1.0000000e+00, 9.9975544e-01],
#        [5.8308535e-04, 1.1096224e-03, 1.0000000e+00, 9.9998653e-01],
#        [5.4551876e-01, 5.6404155e-02, 1.0000000e+00, 9.9824631e-01],
#        [4.8965696e-01, 9.9993485e-01, 9.9989915e-01, 1.6668081e-01]],
#       dtype=float32)

# %%
y_pred[:5]
# Out:
# array([[9.9629015e-01, 9.8922896e-01, 9.9970061e-01, 1.8396446e-01],
#        [5.3559780e-02, 1.8812823e-03, 1.0000000e+00, 9.9975544e-01],
#        [5.8308535e-04, 1.1096224e-03, 1.0000000e+00, 9.9998653e-01],
#        [5.4551876e-01, 5.6404155e-02, 1.0000000e+00, 9.9824631e-01],
#        [4.8965696e-01, 9.9993485e-01, 9.9989915e-01, 1.6668081e-01]],
#       dtype=float32)

# %% [markdown]
# ### Plot X_test with label from our prediction

# %%
pred_values=[np.argmax(i) for i in y_pred]

# %%
y_pred[:5]
# Out:
# array([[9.9629015e-01, 9.8922896e-01, 9.9970061e-01, 1.8396446e-01],
#        [5.3559780e-02, 1.8812823e-03, 1.0000000e+00, 9.9975544e-01],
#        [5.8308535e-04, 1.1096224e-03, 1.0000000e+00, 9.9998653e-01],
#        [5.4551876e-01, 5.6404155e-02, 1.0000000e+00, 9.9824631e-01],
#        [4.8965696e-01, 9.9993485e-01, 9.9989915e-01, 1.6668081e-01]],
#       dtype=float32)

# %%
plt.figure(figsize=(15,8))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(x_test[i])
    plt.title(label_names[pred_values[i]])
plt.tight_layout()

# %% [markdown]
# ### Visualise confusion matrix on a heatmap

# %%
sns.heatmap(confusion_matrix(y_test,pred_values),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***

# %% [markdown]
# # <span style = "color:green;font-size:50px">Great Job!</span>
